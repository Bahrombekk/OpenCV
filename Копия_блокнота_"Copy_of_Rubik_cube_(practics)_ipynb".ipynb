# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Copy_of_Rubik_cube_(practics)_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O cube.png https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Out:
# --2023-04-30 06:25:14--  https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png [following]
# --2023-04-30 06:25:15--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 858445 (838K) [image/png]
# Saving to: ‘cube.png’
#
# cube.png            100%[===================>] 838.33K  --.-KB/s    in 0.008s
#
# 2023-04-30 06:25:15 (97.8 MB/s) - ‘cube.png’ saved [858445/858445]

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import json
from random import randint

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
def show(img,s=8):
  plt.figure(figsize=(s,s),dpi=100)
  plt.imshow(img,cmap='gray')
  plt.show()

# %%
def hsv_opencv(H, S, V):

  H = H//2
  S = S*255//100
  V = V*255//100
  return [H, S, V]

# %%
def get_img(name):
  img=cv2.imread(name)
  img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
  return img,gray

# %%
img=cv2.imread('cube.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)

# %%
show(img)

# %%
HSV1_blue = hsv_opencv(220, 88, 51)
H,S,V=HSV1_blue

# %%
lower_blue = np.array([H-10, 120, 50], dtype=np.uint8)
upper_blue = np.array([H+10, 255, 255], dtype=np.uint8)

# %%
blue = cv2.inRange(hsv_img, lower_blue, upper_blue)

# %%
show(blue)

# %%
HSV_red=hsv_opencv(360, 174, 174)
H,S,V=HSV_red

# %%
lower_red = np.array([H-10, 50, 50], dtype=np.uint8)
upper_red= np.array([H+10, 255, 255], dtype=np.uint8)

# %%
red=cv2.inRange(hsv_img,lower_red,upper_red)

# %%
show(red)

# %%
HSV_yellow=hsv_opencv(45, 161, 44)
H,S,V=HSV_yellow

# %%
lower_yellow=np.array([H-10,100,100],dtype=np.uint8)
upper_yellow=np.array([H+10,255,255],dtype=np.uint8)

# %%
yellow=cv2.inRange(hsv_img,lower_yellow,upper_yellow)

# %%
show(yellow)

# %%
 HSV_green=hsv_opencv(100,161,44)
 H,S,V=HSV_green

# %%
lower_green=np.array([H-10,50,50],dtype=np.uint8)
upper_green=np.array([H+10,255,255],dtype=np.uint8)

# %%
green=cv2.inRange(hsv_img,lower_green,upper_green)

# %%
show(green)

# %%
HSV_brown=hsv_opencv(200, 95, 58)
H,S,V=HSV_brown

# %%
lower_brown=np.array([H-10,150,80],dtype=np.uint8)
upper_brown=np.array([H+10,255,255],dtype=np.uint8)

# %%
brown=cv2.inRange(hsv_img,lower_brown,upper_brown)

# %%
show(brown)
