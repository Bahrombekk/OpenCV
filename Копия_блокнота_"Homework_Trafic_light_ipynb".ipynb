# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Homework_Trafic_light_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/red_stop.jpg
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/yellow_wait.jpg
# Out:
# --2023-05-05 20:20:34--  https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg [following]
# --2023-05-05 20:20:34--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76901 (75K) [image/jpeg]
# Saving to: ‘green_go.jpg’
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = True

# %%
# utility 
def show(img,b=False):
  '''
  Show images
  
  img: image
  return: None
  '''
  plt.imshow(img,cmap='gray')
  plt.grid(b)
  plt.show()

# %%
img=cv2.imread('green_go.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
H,S,V=169//2,38*255//100,73*255//100
HSV=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
lower = np.array([H-10, 60, 125], dtype=np.uint8)
upper = np.array([[H+10, 245, 255]], dtype=np.uint8)
mask=cv2.inRange(HSV,lower,upper)
show(mask)

# %%
img_red=cv2.imread('red_stop.jpg')
img_red=cv2.cvtColor(img_red,cv2.COLOR_BGR2RGB)
HSV=cv2.cvtColor(img_red,cv2.COLOR_RGB2HSV)
H,S,V=359//2,91*255//100,97*255//100
lower = np.array([H-20, 50, 250], dtype=np.uint8)
upper = np.array([[H+20, 255, 255]], dtype=np.uint8)
mask=cv2.inRange(HSV,lower,upper)
show(mask)

# %%
img_yellow=cv2.imread('yellow_wait.jpg')
img_yellow=cv2.cvtColor(img_red,cv2.COLOR_BGR2RGB)
HSV=cv2.cvtColor(img_red,cv2.COLOR_RGB2HSV)
H,S,V=29//2,89*255//100,99*255//100
lower = np.array([H-10, 100, 100], dtype=np.uint8)
upper = np.array([[H+10, 255, 255]], dtype=np.uint8)
mask=cv2.inRange(HSV,lower,upper)
show(mask)

# %%
def get_img(name):
  '''
  name: image name
  return:
    tuple: grayscale image, RGB image
  '''
  # CODE
  img=cv2.imread(name)
  img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  return gray,img

# %%
def get_mask(img):
  '''
  img: grayscale image
  start,stop: color range
  '''
  H,S,V=
  # CODE
  return img_mask

# %%
def get_ROI(img,mask):
  '''
  retrun: ROI_img (grayscale)
  '''
  # CODE
  
  return ROI_img

# %%
RED,RGB_RED = get_img('red_stop.jpg')
GREEN,RGB_GREEN = get_img('green_go.jpg')
YELLOW,RGB_YELLOW = get_img('yellow_wait.jpg')

RED =get_ROI(RGB_RED, get_mask(RGB_RED))
GREEN = get_ROI(RGB_GREEN, get_mask(RGB_GREEN))
YELLOW = get_ROI(RGB_YELLOW, get_mask(RGB_YELLOW))

# %%
show(RED)

# %%
img_red = cv2.inRange(RED,'start color range','stop color range')
img_green = cv2.inRange(GREEN,'start color range','stop color range')
yellow_img = cv2.inRange(YELLOW,'start color range','stop color range')
show(np.hstack((img_red,img_green,yellow_img)))
