# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Copy_of_ONLINE_2023_PIXEL_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
# !wget https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/basic/flatuicolors.png
# Out:
# --2023-04-16 08:46:01--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/basic/flatuicolors.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132 [image/png]
# Saving to: ‘flatuicolors.png’
#
# flatuicolors.png    100%[===================>]     132  --.-KB/s    in 0s
#
# 2023-04-16 08:46:01 (11.0 MB/s) - ‘flatuicolors.png’ saved [132/132]

# %%
# !wget -O image.png https://listimg.pinclipart.com/picdir/s/361-3619294_mario-pixel-art-super-mario-bros-grid-clipart.png
# Out:
# --2023-04-16 08:46:05--  https://listimg.pinclipart.com/picdir/s/361-3619294_mario-pixel-art-super-mario-bros-grid-clipart.png
# Resolving listimg.pinclipart.com (listimg.pinclipart.com)... 173.208.239.244
# Connecting to listimg.pinclipart.com (listimg.pinclipart.com)|173.208.239.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31993 (31K) [image/png]
# Saving to: ‘image.png’
#
# image.png           100%[===================>]  31.24K  --.-KB/s    in 0s
#
# 2023-04-16 08:46:06 (211 MB/s) - ‘image.png’ saved [31993/31993]

# %%
pixel = np.array([[[73,221,88]]])
print(pixel.shape)
# Out:
# (1, 1, 3)

# %%
plt.imshow(pixel)
plt.show()

# %%
img = cv2.imread('flatuicolors.png')

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
print(img)
# Out:
# [[[156 188  26]
#   [113 204  46]
#   [219 152  52]
#   [182  89 155]
#   [ 94  73  52]]
#
#  [[133 160  22]
#   [ 96 174  39]
#   [185 128  41]
#   [173  68 142]
#   [ 80  62  44]]
#
#  [[ 15 196 241]
#   [ 34 126 230]
#   [ 60  76 231]
#   [241 240 236]
#   [166 165 149]]
#
#  [[ 18 156 243]
#   [  0  84 211]
#   [ 43  57 192]
#   [199 195 189]
#   [141 140 127]]]

# %%
img[0,0]
# Out:
# array([156, 188,  26], dtype=uint8)

# %%
img1 = cv2.imread('image.png')

# %%
rasim=img1[:,:,[2,1,0]]

# %%
plt.imshow(rasim,cmap='gray')
plt.show()

# %%
a=cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(a,cmap='gray')
plt.show()
