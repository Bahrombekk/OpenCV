# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import csv

# %%
# !wget -O Salary.csv https://raw.githubusercontent.com/JavohirJalilov/Regression/master/Salary_Data.csv
# Out:
# --2023-06-02 15:32:14--  https://raw.githubusercontent.com/JavohirJalilov/Regression/master/Salary_Data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 454 [text/plain]
# Saving to: ‘Salary.csv’
#
# Salary.csv          100%[===================>]     454  --.-KB/s    in 0s
#
# 2023-06-02 15:32:14 (21.4 MB/s) - ‘Salary.csv’ saved [454/454]

# %%
def read_data(filename):
  data = open(filename)
  data = csv.reader(data)
  next(data)
  return list(data)
  # WRITE YOUR CODE HERE
filename='/content/Salary.csv'
read_data(filename)
# Out:
# [['1.1', '39343.00'],
#  ['1.3', '46205.00'],
#  ['1.5', '37731.00'],
#  ['2.0', '43525.00'],
#  ['2.2', '39891.00'],
#  ['2.9', '56642.00'],
#  ['3.0', '60150.00'],
#  ['3.2', '54445.00'],
#  ['3.2', '64445.00'],
#  ['3.7', '57189.00'],
#  ['3.9', '63218.00'],
#  ['4.0', '55794.00'],
#  ['4.0', '56957.00'],
#  ['4.1', '57081.00'],
#  ['4.5', '61111.00'],
#  ['4.9', '67938.00'],
#  ['5.1', '66029.00'],
#  ['5.3', '83088.00'],
#  ['5.9', '81363.00'],
#  ['6.0', '93940.00'],
#  ['6.8', '91738.00'],
#  ['7.1', '98273.00'],
#  ['7.9', '101302.00'],
#  ['8.2', '113812.00'],
#  ['8.7', '109431.00'],
#  ['9.0', '105582.00'],
#  ['9.5', '116969.00'],
#  ['9.6', '112635.00'],
#  ['10.3', '122391.00'],
#  ['10.5', '121872.00']]

# %%
data_list = read_data('/content/Salary.csv')

# %%
yil=[]
narx=[]
for i in data:
  yil.append(float(i[0]))
  narx.append(float(i[1]))

# %%
plt.scatter(yil,narx,c='r')
plt.show()

# %%
l=[]
for i in yil:
  l.append(9379*i+24692)
plt.plot(yil,l)
plt.show()

# %%
plt.scatter(yil,narx,c='r')
plt.plot(yil,l)
plt.show()

# %%
l3=[]
for narx,l in zip(narx,l):
  l3.append(abs(narx-l))
print(sum(l3)/len(l3))
# Out:
# 4715.160000000001
