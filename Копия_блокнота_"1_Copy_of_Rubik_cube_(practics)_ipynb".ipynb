# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%221_Copy_of_Rubik_cube_(practics)_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O cube.png https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Out:
# --2023-05-02 11:30:18--  https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png [following]
# --2023-05-02 11:30:18--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 858445 (838K) [image/png]
# Saving to: ‘cube.png’
#
# cube.png            100%[===================>] 838.33K  --.-KB/s    in 0.05s
#
# 2023-05-02 11:30:18 (17.2 MB/s) - ‘cube.png’ saved [858445/858445]

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import json
from random import randint

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
def show(img,s=8):
  plt.figure(figsize=(s,s),dpi=100)
  plt.imshow(img,cmap='gray')
  plt.show()

# %%
def hsv_opencv(H, S, V):


  return [H, S, V]

# %%
def get_img(name):
  img = cv2.imread(name)
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  return img,gray

# %%
img,gray = get_img('cube.png')

# %%
show(img)

# %%
show(gray)

# %%
255*68
# Out:
# 17340

# %%
h,s,v = 28,0,0
hsv = cv2.cvtColor(img,cv2.COLOR_RGB2HSV)

# %%
lower = np.array([0,0,150])
upper = np.array([179,4,180])

# %%
yellow = cv2.inRange(hsv,lower,upper)

# %%
show(yellow)
