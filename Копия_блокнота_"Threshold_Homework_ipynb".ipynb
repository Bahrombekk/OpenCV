# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Threshold_Homework_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
# !wget https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/opencv_logo_solid.jpg
# Out:
# --2023-04-28 20:12:51--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/opencv_logo_solid.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137968 (135K) [image/jpeg]
# Saving to: ‘opencv_logo_solid.jpg’
#
# opencv_logo_solid.j 100%[===================>] 134.73K  --.-KB/s    in 0.02s
#
# 2023-04-28 20:12:51 (5.34 MB/s) - ‘opencv_logo_solid.jpg’ saved [137968/137968]

# %%
# utility 
def show(img,b=False):
  plt.figure(figsize=(8,8))#,dpi=d)
  plt.imshow(img,cmap='gray')
  plt.grid(b)
  plt.show()

# %%
def get_images(filename):
  """
  Get image
  Args:
    filename(str): file path
  Returns:
    numpy.ndarray: RGB and Grayscale image
  """
  img=cv2.imread(filename)
  rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  # write code here
  return rgb,gray

# %%
rgb, gray = get_images('opencv_logo_solid.jpg')

# %%
gray_org = gray.copy()

# %%
show(rgb)

# %%
show(gray)

# %%
ret, thresh3 = cv2.threshold(gray,180,255, cv2.THRESH_BINARY)
plt.imshow(thresh3,'gray')

# %%
def get_red_threshold(gray):
  """
  threshold image for red
  """
  # write code here
  
  return red_image

# %%
def get_blue_threshold(gray):
  """
  threshold image for blue
  """
  # write code here
  return blue_image

# %%
def get_green_threshold(gray):
  """
  threshold image for green
  """
  # write code here
  return green_image

# %%
get_red = get_red_threshold(gray)
gray = # delete red color values

# %%
show(gray)

# %%
get_blue = get_blue_threshold(gray)
gray = # delete blue color values

# %%
show(gray)

# %%
get_green = get_green_threshold(gray)
gray = # delete blue color values

# %%
show(get_green)

# %%
h_img1 = np.hstack((gray_org,get_red))
h_img2 = np.hstack((get_green,get_blue))
v_img = np.vstack((h_img1,h_img2))
show(v_img)
