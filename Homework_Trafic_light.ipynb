# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/OpenCV/blob/main/Homework_Trafic_light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/red_stop.jpg
# !wget https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/yellow_wait.jpg
# Out:
# --2023-03-21 16:31:25--  https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg [following]
# --2023-03-21 16:31:25--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/green_go.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76901 (75K) [image/jpeg]
# Saving to: ‘green_go.jpg.1’
#
# green_go.jpg.1      100%[===================>]  75.10K  --.-KB/s    in 0.001s
#
# 2023-03-21 16:31:25 (60.0 MB/s) - ‘green_go.jpg.1’ saved [76901/76901]
#
# --2023-03-21 16:31:25--  https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/red_stop.jpg
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/red_stop.jpg [following]
# --2023-03-21 16:31:25--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/red_stop.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75473 (74K) [image/jpeg]
# Saving to: ‘red_stop.jpg.1’
#
# red_stop.jpg.1      100%[===================>]  73.70K  --.-KB/s    in 0.002s
#
# 2023-03-21 16:31:25 (42.7 MB/s) - ‘red_stop.jpg.1’ saved [75473/75473]
#
# --2023-03-21 16:31:25--  https://github.com/Naxalov/ComputerVision/raw/master/OpenCV/Image%20Processing/traffic_light/level%202/yellow_wait.jpg
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/yellow_wait.jpg [following]
# --2023-03-21 16:31:25--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/OpenCV/Image%20Processing/traffic_light/level%202/yellow_wait.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71367 (70K) [image/jpeg]
# Saving to: ‘yellow_wait.jpg.1’
#
# yellow_wait.jpg.1   100%[===================>]  69.69K  --.-KB/s    in 0.001s
#
# 2023-03-21 16:31:25 (48.0 MB/s) - ‘yellow_wait.jpg.1’ saved [71367/71367]

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = True

# %%
# utility 
def show(img,b=False):
  '''
  Show images
  
  img: image
  return: None
  '''
  plt.imshow(img,cmap='gray')
  plt.grid(b)
  plt.show()

# %%
def get_img(name):
  '''
  name: image name
  return:
    tuple: grayscale image, RGB image
  '''
  # CODE

  return gray,img

# %%
def get_mask(img):
  '''
  img: grayscale image
  start,stop: color range
  '''
  # CODE
  return img_mask

# %%
def get_ROI(img,mask):
  '''
  retrun: ROI_img (grayscale)
  '''
  # CODE
  
  return ROI_img

# %%
RED,RGB_RED = get_img('image path')
GREEN,RGB_GREEN = get_img('image path')
YELLOW,RGB_YELLOW = get_img('image path')

RED =get_ROI(RGB_RED, get_mask(RGB_RED))
GREEN = get_ROI(RGB_GREEN, get_mask(RGB_GREEN))
YELLOW = get_ROI(RGB_YELLOW, get_mask(RGB_YELLOW))

# %%
show(RED)

# %%
img_red = cv2.inRange(RED,'start color range','stop color range')
img_green = cv2.inRange(GREEN,'start color range','stop color range')
yellow_img = cv2.inRange(YELLOW,'start color range','stop color range')
show(np.hstack((img_red,img_green,yellow_img)))
